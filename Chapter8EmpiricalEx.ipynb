# %% [markdown]
# <a href="https://colab.research.google.com/github/kamrankop/pset-cs50/blob/master/Chapter8EmpiricalEx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install statsmodels pandas numpy

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import statistics as st
print(pd.__version__)

import xlrd

from statsmodels.formula.api import ols
# Out:
# 2.3.3

# %%
import pandas as pd

Ch8Data = pd.read_excel('cps_08.xlsx')
print(Ch8Data)
# Out:
#             ahe  year  bachelor  female  age
# 0     38.461540  2008         1       0   33
# 1     12.500000  2008         1       0   31
# 2      9.857142  2008         0       0   30
# 3      8.241758  2008         0       0   30
# 4     17.788462  2008         0       0   31
# ...         ...   ...       ...     ...  ...
# 7706  12.500000  2008         0       0   32
# 7707  24.725275  2008         1       1   28
# 7708  41.208790  2008         1       0   33
# 7709   3.269231  2008         1       1   31
# 7710  13.269231  2008         0       0   30
#
# [7711 rows x 5 columns]

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
#part1

lm1 = ols('ahe~age+female+bachelor',data=Ch8Data).fit()
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    ahe   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     641.5
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):               0.00
# Time:                        19:41:21   Log-Likelihood:                -27944.
# No. Observations:                7711   AIC:                         5.590e+04
# Df Residuals:                    7707   BIC:                         5.592e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6357      1.085     -0.586      0.558      -2.763       1.492
# ...

# %%
#part2

lm2 = ols('np.log(ahe)~age+female+bachelor',data=Ch8Data).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.log(ahe)   R-squared:                       0.201
# Model:                            OLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     644.9
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):               0.00
# Time:                        19:42:42   Log-Likelihood:                -5107.4
# No. Observations:                7711   AIC:                         1.022e+04
# Df Residuals:                    7707   BIC:                         1.025e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.8763      0.056     33.411      0.000       1.766       1.986
# ...

# %%
#part3

lm3 = ols('np.log(ahe)~np.log(age)+female+bachelor',data=Ch8Data).fit()
lm3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.log(ahe)   R-squared:                       0.201
# Model:                            OLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     645.3
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):               0.00
# Time:                        19:44:09   Log-Likelihood:                -5106.8
# No. Observations:                7711   AIC:                         1.022e+04
# Df Residuals:                    7707   BIC:                         1.025e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.0345      0.186     -0.185      0.853      -0.400       0.331
# ...

# %%
TPdiff = ((0.8039 * np.log(36)) - (0.8039 * np.log(35))) * 100
print(TPdiff)
# Out:
# 2.2646567993527267

# %%
#part4

Ch8Data ['age2'] = Ch8Data['age']**2
print(Ch8Data)
# Out:
#             ahe  year  bachelor  female  age  age2
# 0     38.461540  2008         1       0   33  1089
# 1     12.500000  2008         1       0   31   961
# 2      9.857142  2008         0       0   30   900
# 3      8.241758  2008         0       0   30   900
# 4     17.788462  2008         0       0   31   961
# ...         ...   ...       ...     ...  ...   ...
# 7706  12.500000  2008         0       0   32  1024
# 7707  24.725275  2008         1       1   28   784
# 7708  41.208790  2008         1       0   33  1089
# 7709   3.269231  2008         1       1   31   961
# 7710  13.269231  2008         0       0   30   900
#
# [7711 rows x 6 columns]

# %%
lm4 = ols('ahe~age+age2+female+bachelor',data=Ch8Data).fit()
lm4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    ahe   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     481.2
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):               0.00
# Time:                        19:48:16   Log-Likelihood:                -27943.
# No. Observations:                7711   AIC:                         5.590e+04
# Df Residuals:                    7706   BIC:                         5.593e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -8.8373     12.337     -0.716      0.474     -33.021      15.346
# ...

# %%
-8.8373+1.1457*40-0.0095*40*40-3.6635*1+8.0856*1
# Out:
# 26.212799999999998

# %%
#part5: answered by the calculation for the age^2

# %%
#part6

TPF_test = lm4.f_test('(age=0), (age2=0)')
print(TPF_test)
# Out:
# <F test: F=130.87188440543366, p=1.2794267606827984e-56, df_denom=7.71e+03, df_num=2>

# %%
#part7andpart8

Ch8Data["agefem"]=Ch8Data["age"]*Ch8Data["female"]
print(Ch8Data)
# Out:
#             ahe  year  bachelor  female  age  agefem
# 0     38.461540  2008         1       0   33       0
# 1     12.500000  2008         1       0   31       0
# 2      9.857142  2008         0       0   30       0
# 3      8.241758  2008         0       0   30       0
# 4     17.788462  2008         0       0   31       0
# ...         ...   ...       ...     ...  ...     ...
# 7706  12.500000  2008         0       0   32       0
# 7707  24.725275  2008         1       1   28      28
# 7708  41.208790  2008         1       0   33       0
# 7709   3.269231  2008         1       1   31      31
# 7710  13.269231  2008         0       0   30       0
#
# [7711 rows x 6 columns]

# %%
lm7 = ols('np.log(ahe)~age+female+bachelor+agefem',data=Ch8Data).fit()
lm7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.log(ahe)   R-squared:                       0.203
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     489.8
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):               0.00
# Time:                        20:00:41   Log-Likelihood:                -5097.5
# No. Observations:                7711   AIC:                         1.020e+04
# Df Residuals:                    7706   BIC:                         1.024e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6602      0.074     22.358      0.000       1.515       1.806
# ...

# %%
#part10 following myeconlab question, the regression asked about is age x bachelor

Ch8Data['agebachelor']=Ch8Data['age']*Ch8Data['bachelor']
print(Ch8Data)
# Out:
#             ahe  year  bachelor  female  age  agefem  agebachelor
# 0     38.461540  2008         1       0   33       0           33
# 1     12.500000  2008         1       0   31       0           31
# 2      9.857142  2008         0       0   30       0            0
# 3      8.241758  2008         0       0   30       0            0
# 4     17.788462  2008         0       0   31       0            0
# ...         ...   ...       ...     ...  ...     ...          ...
# 7706  12.500000  2008         0       0   32       0            0
# 7707  24.725275  2008         1       1   28      28           28
# 7708  41.208790  2008         1       0   33       0           33
# 7709   3.269231  2008         1       1   31      31           31
# 7710  13.269231  2008         0       0   30       0            0
#
# [7711 rows x 7 columns]

# %%
lm9 = ols('np.log(ahe)~age+female+bachelor+agebachelor',data=Ch8Data).fit()
lm9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.log(ahe)   R-squared:                       0.203
# Model:                            OLS   Adj. R-squared:                  0.202
# Method:                 Least Squares   F-statistic:                     489.8
# Date:                Sun, 02 Nov 2025   Prob (F-statistic):               0.00
# Time:                        20:01:25   Log-Likelihood:                -5097.5
# No. Observations:                7711   AIC:                         1.020e+04
# Df Residuals:                    7706   BIC:                         1.024e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.1168      0.078     27.182      0.000       1.964       2.270
# ...

# %%
2.1168+0.0192*40-0.1844*1-0.0649*1+0.0167*40
# Out:
# 3.3034999999999997
